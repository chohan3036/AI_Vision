# %%
import tensorflow as tf
from tensorflow import keras

import os
import matplotlib.pyplot as plt

# %%
url = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
path_to_zip = keras.utils.get_file(fname='cats_and_dogs.zip',
                                   origin=url,
                                   extract=True,
                                   cache_dir='/content')
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step

# %%
data_path = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')
# !find $data_path -type d
# Out:
# /content/datasets/cats_and_dogs_filtered
# /content/datasets/cats_and_dogs_filtered/validation
# /content/datasets/cats_and_dogs_filtered/validation/dogs
# /content/datasets/cats_and_dogs_filtered/validation/cats
# /content/datasets/cats_and_dogs_filtered/train
# /content/datasets/cats_and_dogs_filtered/train/dogs
# /content/datasets/cats_and_dogs_filtered/train/cats

# %%
base_dir = data_path
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# %%
print(train_dir)
print(validation_dir)
# Out:
# /content/datasets/cats_and_dogs_filtered/train
# /content/datasets/cats_and_dogs_filtered/validation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# 알아서 3차원 텐서로 만들어줘서 reshape 할 필요 없음
# 모든 이미지를 1/255로 스케일 조정
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    # 타깃 디렉토리
    directory=train_dir,
    # 모든 이미지를 150 x 150 크기로 바꿉니다
    target_size=(150, 150),
    batch_size=20,
    shuffle=True,
    # binary_crossentropy 손실을 사용하기 때문에 이진 레이블이 필요
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    directory=validation_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-cc08786c98d0> in <module>()
# ----> 1 from tensorflow import models, layers
#
# ImportError: cannot import name 'models'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def build_model():
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu',
                                  input_shape=(150, 150, 3)))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512, activation='relu'))
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    model.summary()
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 893 = (3 * 3) * 3 * 32
# 2차원 필터 크기 * 컬러 필터 depth * 필터 개수

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator) - 1,
    epochs=20,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)
# Out:
# Epoch 1/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.7378 - accuracy: 0.5025 - val_loss: 0.6865 - val_accuracy: 0.5730
# Epoch 2/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.6920 - accuracy: 0.5682 - val_loss: 0.6718 - val_accuracy: 0.6050
# Epoch 3/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.6533 - accuracy: 0.6460 - val_loss: 0.8073 - val_accuracy: 0.5560
# Epoch 4/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.6208 - accuracy: 0.6702 - val_loss: 0.6469 - val_accuracy: 0.6510
# Epoch 5/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.5777 - accuracy: 0.7278 - val_loss: 0.5443 - val_accuracy: 0.7280
# Epoch 6/20
# 99/99 [==============================] - 10s 106ms/step - loss: 0.5217 - accuracy: 0.7465 - val_loss: 0.6628 - val_accuracy: 0.6630
# Epoch 7/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.4870 - accuracy: 0.7758 - val_loss: 0.6785 - val_accuracy: 0.6770
# Epoch 8/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.4352 - accuracy: 0.8010 - val_loss: 0.5841 - val_accuracy: 0.7050
# Epoch 9/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.3850 - accuracy: 0.8237 - val_loss: 0.5761 - val_accuracy: 0.7650
# Epoch 10/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.3381 - accuracy: 0.8444 - val_loss: 0.5192 - val_accuracy: 0.7470
# Epoch 11/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.2944 - accuracy: 0.8793 - val_loss: 0.5939 - val_accuracy: 0.7310
# Epoch 12/20
# 99/99 [==============================] - 11s 107ms/step - loss: 0.2664 - accuracy: 0.8929 - val_loss: 0.5855 - val_accuracy: 0.7600
# Epoch 13/20
# 99/99 [==============================] - 11s 107ms/step - loss: 0.1996 - accuracy: 0.9202 - val_loss: 0.6811 - val_accuracy: 0.7490
# Epoch 14/20
# 99/99 [==============================] - 11s 107ms/step - loss: 0.1437 - accuracy: 0.9419 - val_loss: 1.0084 - val_accuracy: 0.7310
# Epoch 15/20
# 99/99 [==============================] - 10s 106ms/step - loss: 0.1364 - accuracy: 0.9465 - val_loss: 1.0562 - val_accuracy: 0.7510
# Epoch 16/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.1102 - accuracy: 0.9626 - val_loss: 0.9842 - val_accuracy: 0.7400
# Epoch 17/20
# 99/99 [==============================] - 10s 105ms/step - loss: 0.1079 - accuracy: 0.9641 - val_loss: 0.8686 - val_accuracy: 0.7550
# Epoch 18/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.0800 - accuracy: 0.9717 - val_loss: 1.0152 - val_accuracy: 0.7420
# Epoch 19/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.0885 - accuracy: 0.9778 - val_loss: 1.0126 - val_accuracy: 0.7280
# Epoch 20/20
# 99/99 [==============================] - 10s 104ms/step - loss: 0.0641 - accuracy: 0.9808 - val_loss: 1.5315 - val_accuracy: 0.7630

# %%
test_loss, test_acc = model.evaluate(validation_generator)
# Out:
# 50/50 [==============================] - 3s 62ms/step - loss: 1.5315 - accuracy: 0.7630

# %%
data_batch, labels_batch = next(train_generator)
print('배치 데이터 크기:', data_batch.shape)
print('배치 레이블 크기:', labels_batch.shape)
# Out:
# 배치 데이터 크기: (20, 150, 150, 3)
# 배치 레이블 크기: (20,)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
    keras.callbacks.ModelCheckpoint(filepath='./checkpoint', monitor='val_accuracy',
                                    save_best_only=True)
]

# %%
callback_model = build_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = callback_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=30,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 100/100 [==============================] - ETA: 0s - loss: 0.8305 - accuracy: 0.5190WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# 100/100 [==============================] - 12s 122ms/step - loss: 0.8305 - accuracy: 0.5190 - val_loss: 0.6900 - val_accuracy: 0.5000
# Epoch 2/30
# 100/100 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.5520INFO:tensorflow:Assets written to: ./checkpoint/assets
# 100/100 [==============================] - 12s 119ms/step - loss: 0.7049 - accuracy: 0.5520 - val_loss: 0.6518 - val_accuracy: 0.6170
# Epoch 3/30
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6688 - accuracy: 0.6420 - val_loss: 0.6618 - val_accuracy: 0.5910
# Epoch 4/30
# 100/100 [==============================] - ETA: 0s - loss: 0.6007 - accuracy: 0.6725INFO:tensorflow:Assets written to: ./checkpoint/assets
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6007 - accuracy: 0.6725 - val_loss: 0.5912 - val_accuracy: 0.6850
# Epoch 5/30
# 100/100 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7400INFO:tensorflow:Assets written to: ./checkpoint/assets
# 100/100 [==============================] - 12s 118ms/step - loss: 0.5439 - accuracy: 0.7400 - val_loss: 0.5686 - val_accuracy: 0.7090
# Epoch 6/30
# 100/100 [==============================] - 11s 107ms/step - loss: 0.5006 - accuracy: 0.7490 - val_loss: 0.5911 - val_accuracy: 0.7050
# Epoch 7/30
# 100/100 [==============================] - 11s 106ms/step - loss: 0.4635 - accuracy: 0.7905 - val_loss: 0.6136 - val_accuracy: 0.6700
# Epoch 8/30
# 100/100 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8180INFO:tensorflow:Assets written to: ./checkpoint/assets
# 100/100 [==============================] - 12s 119ms/step - loss: 0.4135 - accuracy: 0.8180 - val_loss: 0.6049 - val_accuracy: 0.7510
# Epoch 9/30
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3563 - accuracy: 0.8450 - val_loss: 0.7078 - val_accuracy: 0.7460
# Epoch 10/30
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2916 - accuracy: 0.8745 - val_loss: 0.6724 - val_accuracy: 0.7380
# Epoch 11/30
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2384 - accuracy: 0.8990 - val_loss: 0.7898 - val_accuracy: 0.7040

# %%
callback_test_loss, callback_test_acc = callback_model.evaluate(validation_generator)
# Out:
# 50/50 [==============================] - 3s 64ms/step - loss: 0.7898 - accuracy: 0.7040

# %%
loaded_model = keras.models.load_model('/content/checkpoint')

# %%
test_loss, test_acc = loaded_model.evaluate(validation_generator)
# Out:
# 50/50 [==============================] - 3s 65ms/step - loss: 0.6049 - accuracy: 0.7510

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git

# %%
# %cd "./Mask_RCNN/"
# Out:
# /content/Mask_RCNN

# %%
# !python setup.py install

# %% [markdown]
# ### Matterport 패키지를 이용하여 pretrained coco 모델을 로딩 후 단일 이미지와 영상 Segmentation 수행.

# %%
import os
import sys
import random
import math
import numpy as np
import cv2

# %% [markdown]
# #### Matterport로 pretrained된 coco weight 모델을 다운로드

# %%
from mrcnn import utils

# %%
ROOT_DIR = "/content/Mask_RCNN"

COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Downloading pretrained model to /content/Mask_RCNN/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %% [markdown]
# #### MASK RCNN 모델을 위한 Config 설정

# %%
from mrcnn.config import Config

# %%
infer_config = Config()
infer_config.BATCH_SIZE=4
infer_config.display()

# %%
# Config 클래스를 상속받아서 사용
# 환경 변수는 모두 대문자 
class InferenceConfig(Config):
    # inference시에는 batch size를 1로 설정. 그리고 IMAGES_PER_GPU도 1로 설정. 
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    # NAME은 반드시 주어야 한다. 
    NAME='coco_infer'
    NUM_CLASSES=81

infer_config = InferenceConfig()
infer_config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco_infer
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# #### COCO ID와 클래스명 매핑

# %%
# matterport는 0을 Background로, 1부터 80까지 coco dataset 클래스 id/클래스 명 매핑. 
labels_to_names = {0:'BG',1: 'person',2: 'bicycle',3: 'car',4: 'motorbike',5: 'aeroplane',6: 'bus',7: 'train',8: 'truck',9: 'boat',10: 'traffic light',
                   11: 'fire hydrant',12: 'stop sign',13: 'parking meter',14: 'bench',15: 'bird',16: 'cat',17: 'dog',18: 'horse',19: 'sheep',20: 'cow',
                   21: 'elephant',22: 'bear',23: 'zebra',24: 'giraffe',25: 'backpack',26: 'umbrella',27: 'handbag',28: 'tie',29: 'suitcase',30: 'frisbee',
                   31: 'skis',32: 'snowboard',33: 'sports ball',34: 'kite',35: 'baseball bat',36: 'baseball glove',37: 'skateboard',38: 'surfboard',39: 'tennis racket',40: 'bottle',
                   41: 'wine glass',42: 'cup',43: 'fork',44: 'knife',45: 'spoon',46: 'bowl',47: 'banana',48: 'apple',49: 'sandwich',50: 'orange',
                   51: 'broccoli',52: 'carrot',53: 'hot dog',54: 'pizza',55: 'donut',56: 'cake',57: 'chair',58: 'sofa',59: 'pottedplant',60: 'bed',
                   61: 'diningtable',62: 'toilet',63: 'tvmonitor',64: 'laptop',65: 'mouse',66: 'remote', 67: 'keyboard',68: 'cell phone',69: 'microwave',70: 'oven',
                   71: 'toaster',72: 'sink',73: 'refrigerator',74: 'book',75: 'clock',76: 'vase',77: 'scissors',78: 'teddy bear',79: 'hair drier',80: 'toothbrush' }

# %%
import mrcnn.model as modellib
# Out:
# Using TensorFlow backend.

# %%
# MS-COCO 기반으로 Pretrained 된 모델을 로딩
MODEL_DIR = os.path.join(ROOT_DIR,'snapshots') 
print(MODEL_DIR)
model = modellib.MaskRCNN(mode="inference",  model_dir=MODEL_DIR, config=infer_config)

model.load_weights(COCO_MODEL_PATH, by_name=True)
# Out:
# /content/Mask_RCNN/snapshots
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /content/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
# !wget "https://drive.google.com/uc?export=download&id=1g2WgLM_nc0GWgKOIpJzldqYnJIwju0eJ" \
      -O "beatles01.jpg"
# Out:
# --2020-10-27 13:00:48--  https://drive.google.com/uc?export=download&id=1g2WgLM_nc0GWgKOIpJzldqYnJIwju0eJ
# Resolving drive.google.com (drive.google.com)... 108.177.126.100, 108.177.126.113, 108.177.126.101, ...
# Connecting to drive.google.com (drive.google.com)|108.177.126.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/06b88k3qlmjis4go8im4qhdkhokpjhmq/1603803600000/13472183013488020071/*/1g2WgLM_nc0GWgKOIpJzldqYnJIwju0eJ?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-10-27 13:00:48--  https://doc-04-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/06b88k3qlmjis4go8im4qhdkhokpjhmq/1603803600000/13472183013488020071/*/1g2WgLM_nc0GWgKOIpJzldqYnJIwju0eJ?e=download
# Resolving doc-04-94-docs.googleusercontent.com (doc-04-94-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-04-94-docs.googleusercontent.com (doc-04-94-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 383118 (374K) [image/jpeg]
# Saving to: ‘beatles01.jpg’
#
# beatles01.jpg       100%[===================>] 374.14K  --.-KB/s    in 0.003s
#
# 2020-10-27 13:00:48 (134 MB/s) - ‘beatles01.jpg’ saved [383118/383118]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
beatles_img = cv2.imread('beatles01.jpg')
# matterport는 내부적으로 image처리를 위해 skimage를 이용하므로 BGR2RGB처리함. 
beatles_img_rgb = cv2.cvtColor(beatles_img, cv2.COLOR_BGR2RGB)
 
results = model.detect([beatles_img_rgb], verbose=1)
# Out:
# Processing 1 images
# image                    shape: (633, 806, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
len(results), results[0]
# Out:
# (1,
#  {'class_ids': array([1, 1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int32),
#   'masks': array([[[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          ...,
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]]),
#   'rois': array([[260, 552, 572, 729],
#          [265, 228, 551, 375],
#          [257,  47, 561, 206],
#          [276, 395, 555, 552],
#          [226, 607, 294, 627],
#          [236, 473, 260, 502],
#          [224, 436, 241, 455],
#          [227, 453, 247, 472],
#          [247, 139, 345, 257],
#          [237, 489, 283, 516],
#          [224, 381, 239, 399],
#          [217, 364, 229, 378],
#          [228, 508, 296, 583],
#          [233, 313, 266, 348],
#          [218, 399, 228, 413],
#          [221, 424, 233, 437],
#          [218, 412, 228, 424],
#          [231, 466, 254, 479]], dtype=int32),
#   'scores': array([0.9998393 , 0.9998117 , 0.99958915, 0.9994247 , 0.9921353 ,
#          0.9794605 , 0.97927654, 0.96658874, 0.9606329 , 0.9545477 ,
#          0.93600786, 0.92482126, 0.918216  , 0.91627973, 0.8387303 ,
#          0.8154052 , 0.80258876, 0.72912586], dtype=float32)})

# %%
# results[0]['masks']는 object 별로 mask가 전체 이미지에 대해서 layered된 image 배열을 가지고 있음.  
results[0]['rois'].shape, results[0]['scores'].shape, results[0]['class_ids'].shape, results[0]['masks'].shape
# Out:
# ((18, 4), (18,), (18,), (633, 806, 18))

# %%
from mrcnn import visualize

# %%
r = results[0]
class_names = [value for value in labels_to_names.values()]
visualize.display_instances(beatles_img_rgb, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])

# %%
# !wget "https://drive.google.com/uc?export=download&id=1KmWm2uvVLURNzwIvCiwXLPe6wGSt5CnF" \
      -O 'john_wick01.jpg'
# Out:
# --2020-10-27 13:12:47--  https://drive.google.com/uc?export=download&id=1KmWm2uvVLURNzwIvCiwXLPe6wGSt5CnF
# Resolving drive.google.com (drive.google.com)... 108.177.126.101, 108.177.126.138, 108.177.126.102, ...
# Connecting to drive.google.com (drive.google.com)|108.177.126.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/850kuekpqih97vfrht061tv8n2n3ee16/1603804350000/13472183013488020071/*/1KmWm2uvVLURNzwIvCiwXLPe6wGSt5CnF?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-10-27 13:12:48--  https://doc-14-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/850kuekpqih97vfrht061tv8n2n3ee16/1603804350000/13472183013488020071/*/1KmWm2uvVLURNzwIvCiwXLPe6wGSt5CnF?e=download
# Resolving doc-14-94-docs.googleusercontent.com (doc-14-94-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-14-94-docs.googleusercontent.com (doc-14-94-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330283 (323K) [image/jpeg]
# Saving to: ‘john_wick01.jpg’
#
# john_wick01.jpg     100%[===================>] 322.54K  --.-KB/s    in 0.002s
#
# 2020-10-27 13:12:48 (128 MB/s) - ‘john_wick01.jpg’ saved [330283/330283]

# %%
wick_img = cv2.imread('john_wick01.jpg')
wick_img_rgb = cv2.cvtColor(wick_img, cv2.COLOR_BGR2RGB)

# %%
import time

# %%
def get_segment_result(img_array_list, verbose):
    
    start_time = time.time()
    results = model.detect(img_array_list, verbose=1)
    
    if verbose==1:
        print('## inference time:{0:}'.format(time.time()-start_time))
    
    return results

# %%
r = get_segment_result([wick_img_rgb], verbose=1)[0]
visualize.display_instances(wick_img_rgb, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])
# Out:
# Processing 1 images
# image                    shape: (450, 814, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34269094467163086

# %% [markdown]
# ### Video에 Segmentation 적용
# * MaskRCNN 패키지는 visualize.display_instances() 함수내부에서 matplotlib를 이용하여 자체 시각화를 수행.
# * Video segment instance에 적용하기 위해서 bounding box와 instance masking을 적용하는 별도의 함수 생성.

# %%
from mrcnn.visualize import *

# %%
def get_segmented_image(img_array, boxes, masks, class_ids, class_names,
                      scores=None, show_mask=True, show_bbox=True, colors=None, captions=None):
   
    # Number of instances
    N = boxes.shape[0]
    if not N:
        print("\n*** No instances to display *** \n")
    else:
        assert boxes.shape[0] == masks.shape[-1] == class_ids.shape[0]
    

    # Generate random colors
    colors = colors or random_colors(N)

    # Show area outside image boundaries.
    height, width = img_array.shape[:2]

    masked_image = img_array.astype(np.uint32).copy()

    for i in range(N):
        color = np.array(colors[i])*255
        color = color.tolist()

        # Bounding box
        if not np.any(boxes[i]):
            # Skip this instance. Has no bbox. Likely lost in image cropping.
            continue
        y1, x1, y2, x2 = boxes[i]
        
        if show_bbox:
            cv2.rectangle(img_array, (x1, y1), (x2, y2), color, thickness=1 )

        # Label
        if not captions:
            class_id = class_ids[i]
            score = scores[i] if scores is not None else None
            label = class_names[class_id]
            caption = "{} {:.3f}".format(label, score) if score else label
        else:
            caption = captions[i]
            
        cv2.putText(img_array, caption, (x1, y1+8), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), thickness=1)
        
        # Mask
        # 클래스별 mask 정보를 추출 
        mask = masks[:, :, i]
        if show_mask:
            # visualize 모듈의 apply_mask()를 적용하여 masking 수행.
            img_array = apply_mask(img_array, mask, color)
            
            # mask에 contour 적용. 
            padded_mask = np.zeros(
                            (mask.shape[0] + 2, mask.shape[1] + 2), dtype=np.uint8)
            padded_mask[1:-1, 1:-1] = mask
            contours = find_contours(padded_mask, 0.5)
            for verts in contours:
                # padding 제거. 아래에서 verts를 32bit integer로 변경해야 polylines()에서 오류 발생하지 않음. 
                verts = verts.astype(np.int32)
                #x, y 좌표 교체
                verts = np.fliplr(verts) - 1
                cv2.polylines(img_array, [verts], True, color, thickness=1)
    
    return img_array

# %% [markdown]
# ####  단일 IMAGE에 적용

# %%
import time

wick_img = cv2.imread('john_wick01.jpg')
wick_img_rgb = cv2.cvtColor(wick_img, cv2.COLOR_BGR2RGB)

r = get_segment_result([wick_img_rgb], verbose=1)[0]
segmented_img = get_segmented_image(wick_img_rgb, r['rois'], r['masks'], r['class_ids'], 
                                    class_names, r['scores'])

plt.figure(figsize=(16, 16))
plt.imshow(segmented_img)
# Out:
# Processing 1 images
# image                    shape: (450, 814, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30193281173706055

# %% [markdown]
# #### Video Segmentation 적용

# %%
# !wget "https://drive.google.com/uc?export=download&id=1a8bHxT_Xyin15C__epadFEh5J5IFC04r" \
      -O "John_Wick_small.mp4"
# Out:
# --2020-10-27 13:23:12--  https://drive.google.com/uc?export=download&id=1a8bHxT_Xyin15C__epadFEh5J5IFC04r
# Resolving drive.google.com (drive.google.com)... 74.125.143.139, 74.125.143.100, 74.125.143.113, ...
# Connecting to drive.google.com (drive.google.com)|74.125.143.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/r220rjig995jpd18b8i9vkbu2818ofhi/1603804950000/13472183013488020071/*/1a8bHxT_Xyin15C__epadFEh5J5IFC04r?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-10-27 13:23:13--  https://doc-00-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/r220rjig995jpd18b8i9vkbu2818ofhi/1603804950000/13472183013488020071/*/1a8bHxT_Xyin15C__epadFEh5J5IFC04r?e=download
# Resolving doc-00-94-docs.googleusercontent.com (doc-00-94-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-00-94-docs.googleusercontent.com (doc-00-94-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1794863 (1.7M) [video/mp4]
# Saving to: ‘John_Wick_small.mp4’
#
# John_Wick_small.mp4 100%[===================>]   1.71M  --.-KB/s    in 0.009s
#
# 2020-10-27 13:23:13 (182 MB/s) - ‘John_Wick_small.mp4’ saved [1794863/1794863]

# %%
video_input_path = 'John_Wick_small.mp4'
# video output 의 포맷은 avi 로 반드시 설정 필요. 
video_output_path = 'John_Wick_small_matterport01.avi'

cap = cv2.VideoCapture(video_input_path)
codec = cv2.VideoWriter_fourcc(*'XVID')
fps = round(cap.get(cv2.CAP_PROP_FPS))

vid_writer = cv2.VideoWriter(video_output_path, codec, fps, (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print("총 Frame 개수: {0:}".format(total))

# %%
frame_index = 0
while True:
    
    hasFrame, image_frame = cap.read()
    if not hasFrame:
        print('End of frame')
        break
    
    frame_index += 1
    print("frame index:{0:}".format(frame_index), end=" ")
    r = get_segment_result([image_frame], verbose=1)[0]
    segmented_img = get_segmented_image(image_frame, r['rois'], r['masks'], r['class_ids'], 
                                    class_names, r['scores'])
    vid_writer.write(segmented_img)
    
vid_writer.release()
cap.release()
# Out:
# 총 Frame 개수: 58
# frame index:1 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29893994331359863
# frame index:2 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.27876949310302734
# frame index:3 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28874897956848145
# frame index:4 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.27725911140441895
# frame index:5 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2848093509674072
# frame index:6 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2801516056060791
# frame index:7 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2944183349609375
# frame index:8 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.281019926071167
# frame index:9 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28966617584228516
# frame index:10 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29368042945861816
# frame index:11 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29125332832336426
# frame index:12 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3082568645477295
# frame index:13 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2940504550933838
# frame index:14 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30072665214538574
# frame index:15 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28873372077941895
# frame index:16 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29410576820373535
# frame index:17 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28392863273620605
# frame index:18 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2907993793487549
# frame index:19 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29088544845581055
# frame index:20 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29151034355163574
# frame index:21 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2985994815826416
# frame index:22 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28928303718566895
# frame index:23 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2842381000518799
# frame index:24 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29778099060058594
# frame index:25 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2787790298461914
# frame index:26 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2974228858947754
# frame index:27 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28837037086486816
# frame index:28 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2884969711303711
# frame index:29 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29427003860473633
# frame index:30 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29348015785217285
# frame index:31 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30655574798583984
# frame index:32 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28913402557373047
# frame index:33 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28984808921813965
# frame index:34 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29116106033325195
# frame index:35 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2869255542755127
# frame index:36 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29228639602661133
# frame index:37 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2878866195678711
# frame index:38 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29125165939331055
# frame index:39 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2959427833557129
# frame index:40 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30197978019714355
# frame index:41 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2957158088684082
# frame index:42 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29914021492004395
# frame index:43 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2998392581939697
# frame index:44 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2965118885040283
# frame index:45 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29250502586364746
# frame index:46 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29647254943847656
# frame index:47 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28240203857421875
# frame index:48 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2944009304046631
# frame index:49 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29819178581237793
# frame index:50 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30478405952453613
# frame index:51 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28374242782592773
# frame index:52 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.30182838439941406
# frame index:53 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2830617427825928
# frame index:54 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.2995147705078125
# frame index:55 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29425048828125
# frame index:56 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.29411792755126953
# frame index:57 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3034372329711914
# frame index:58 Processing 1 images
# image                    shape: (460, 1072, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1072.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.28880953788757324
# End of frame

# %% [markdown]
# #### 다른 동영상에 적용.

# %%
# !wget "https://drive.google.com/uc?export=download&id=1IrwtHOOIo8J9W9nArdfDrDKJVoSad_Ta" \
      -O "London_Street.mp4"
# Out:
# --2020-10-25 16:50:24--  https://drive.google.com/uc?export=download&id=1IrwtHOOIo8J9W9nArdfDrDKJVoSad_Ta
# Resolving drive.google.com (drive.google.com)... 108.177.126.102, 108.177.126.138, 108.177.126.101, ...
# Connecting to drive.google.com (drive.google.com)|108.177.126.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bplumun71iq5ujcehj3c5vqvclpdrc11/1603644600000/13472183013488020071/*/1IrwtHOOIo8J9W9nArdfDrDKJVoSad_Ta?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-10-25 16:50:27--  https://doc-04-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bplumun71iq5ujcehj3c5vqvclpdrc11/1603644600000/13472183013488020071/*/1IrwtHOOIo8J9W9nArdfDrDKJVoSad_Ta?e=download
# Resolving doc-04-94-docs.googleusercontent.com (doc-04-94-docs.googleusercontent.com)... 74.125.128.132, 2a00:1450:4013:c02::84
# Connecting to doc-04-94-docs.googleusercontent.com (doc-04-94-docs.googleusercontent.com)|74.125.128.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [video/mp4]
# Saving to: ‘London_Street.mp4’
#
# London_Street.mp4       [  <=>               ]  23.77M  52.3MB/s    in 0.5s
#
# 2020-10-25 16:50:28 (52.3 MB/s) - ‘London_Street.mp4’ saved [24928050]

# %%
video_input_path = 'London_Street.mp4'
# video output 의 포맷은 avi 로 반드시 설정 필요. 
video_output_path = 'London_Street_matterport01.avi'

cap = cv2.VideoCapture(video_input_path)
codec = cv2.VideoWriter_fourcc(*'XVID')
fps = round(cap.get(cv2.CAP_PROP_FPS))
vid_writer = cv2.VideoWriter(video_output_path, codec, fps, (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print("총 Frame 개수: {0:}".format(total))

# %%
frame_index = 0
while True:
    
    hasFrame, image_frame = cap.read()
    if not hasFrame:
        print('End of frame')
        break
    
    frame_index += 1
    print("frame index:{0:}".format(frame_index), end=" ")
    r = get_segment_result([image_frame], verbose=1)[0]
    segmented_img = get_segmented_image(image_frame, r['rois'], r['masks'], r['class_ids'], 
                                    class_names, r['scores'])
    vid_writer.write(segmented_img)
    
vid_writer.release()
cap.release()
# Out:
# 총 Frame 개수: 489
# frame index:1 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3610234260559082
# frame index:2 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34191322326660156
# frame index:3 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33597660064697266
# frame index:4 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3315913677215576
# frame index:5 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34163451194763184
# frame index:6 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3361508846282959
# frame index:7 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3441894054412842
# frame index:8 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33333754539489746
# frame index:9 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3527388572692871
# frame index:10 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3408985137939453
# frame index:11 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3349449634552002
# frame index:12 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33454370498657227
# frame index:13 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35514211654663086
# frame index:14 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3484055995941162
# frame index:15 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3564474582672119
# frame index:16 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3522305488586426
# frame index:17 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33509159088134766
# frame index:18 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3439011573791504
# frame index:19 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34675145149230957
# frame index:20 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34653711318969727
# frame index:21 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34699344635009766
# frame index:22 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3431892395019531
# frame index:23 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34340596199035645
# frame index:24 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35006141662597656
# frame index:25 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34978246688842773
# frame index:26 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34113216400146484
# frame index:27 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34914517402648926
# frame index:28 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3587212562561035
# frame index:29 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34462952613830566
# frame index:30 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3447399139404297
# frame index:31 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3541724681854248
# frame index:32 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33919382095336914
# frame index:33 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34305882453918457
# frame index:34 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3588860034942627
# frame index:35 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3500678539276123
# frame index:36 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35895586013793945
# frame index:37 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3479142189025879
# frame index:38 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34209108352661133
# frame index:39 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3428153991699219
# frame index:40 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3401639461517334
# frame index:41 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3418726921081543
# frame index:42 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3633859157562256
# frame index:43 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34851622581481934
# frame index:44 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3355534076690674
# frame index:45 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.338939905166626
# frame index:46 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33481836318969727
# frame index:47 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3405025005340576
# frame index:48 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34061169624328613
# frame index:49 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3499782085418701
# frame index:50 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34380507469177246
# frame index:51 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.334822416305542
# frame index:52 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3385467529296875
# frame index:53 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33745718002319336
# frame index:54 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34182047843933105
# frame index:55 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.335315465927124
# frame index:56 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3407280445098877
# frame index:57 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33708715438842773
# frame index:58 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3339965343475342
# frame index:59 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3408355712890625
# frame index:60 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33847832679748535
# frame index:61 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3441352844238281
# frame index:62 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3468587398529053
# frame index:63 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3305394649505615
# frame index:64 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3287649154663086
# frame index:65 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3326711654663086
# frame index:66 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3343329429626465
# frame index:67 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.32943296432495117
# frame index:68 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3342001438140869
# frame index:69 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33275914192199707
# frame index:70 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3219883441925049
# frame index:71 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3342421054840088
# frame index:72 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33623385429382324
# frame index:73 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3476266860961914
# frame index:74 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35985398292541504
# frame index:75 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3308584690093994
# frame index:76 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.345566987991333
# frame index:77 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.344834566116333
# frame index:78 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33747100830078125
# frame index:79 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3444364070892334
# frame index:80 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3464686870574951
# frame index:81 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34741878509521484
# frame index:82 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35939979553222656
# frame index:83 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35169363021850586
# frame index:84 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3451507091522217
# frame index:85 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3451974391937256
# frame index:86 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33162856101989746
# frame index:87 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35177135467529297
# frame index:88 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3448624610900879
# frame index:89 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3569629192352295
# frame index:90 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35350966453552246
# frame index:91 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3504025936126709
# frame index:92 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3525528907775879
# frame index:93 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3494136333465576
# frame index:94 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3453347682952881
# frame index:95 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34343791007995605
# frame index:96 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34786486625671387
# frame index:97 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3510422706604004
# frame index:98 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34477996826171875
# frame index:99 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3383002281188965
# frame index:100 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34509897232055664
# frame index:101 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35119128227233887
# frame index:102 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.337432861328125
# frame index:103 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3356204032897949
# frame index:104 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3451414108276367
# frame index:105 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35599327087402344
# frame index:106 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# ...
# ## inference time:0.357058048248291
# frame index:455 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34551405906677246
# frame index:456 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3390183448791504
# frame index:457 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3417353630065918
# frame index:458 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33622264862060547
# frame index:459 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3517425060272217
# frame index:460 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3422250747680664
# frame index:461 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33580446243286133
# frame index:462 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34858012199401855
# frame index:463 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34371113777160645
# frame index:464 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3501737117767334
# frame index:465 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.33510351181030273
# frame index:466 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34903573989868164
# frame index:467 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.34573817253112793
# frame index:468 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3413717746734619
# frame index:469 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3595757484436035
# frame index:470 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3581414222717285
# frame index:471 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35294675827026367
# frame index:472 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3654658794403076
# frame index:473 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3500185012817383
# frame index:474 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.36017441749572754
# frame index:475 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35457801818847656
# frame index:476 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3746466636657715
# frame index:477 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.349315881729126
# frame index:478 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3644092082977295
# frame index:479 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3552391529083252
# frame index:480 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3584170341491699
# frame index:481 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3545823097229004
# frame index:482 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35184335708618164
# frame index:483 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3562333583831787
# frame index:484 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3621859550476074
# frame index:485 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3413858413696289
# frame index:486 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.37767982482910156
# frame index:487 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.35454320907592773
# frame index:488 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.37094569206237793
# frame index:489 Processing 1 images
# image                    shape: (684, 1216, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1216.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ## inference time:0.3425414562225342
# End of frame
